# %% [raw]
# Predicting Restaurant Food Cost
#
# Who doesn’t love food? All of us must have craving for at least a few favourite food items, we may also have a few places where we like to get them, a restaurant which serves our favourite food the way we want it to be.
#
# But there is one factor that will make us reconsider having our favourite food from our favourite restaurant, the cost.
#
# Here in this hackathon, you will be predicting the cost of the food served by the restaurants across different cities in India.
#
# You will use your Data Science skills to investigate the factors that really affect the cost, and who knows maybe you will even gain some very interesting insights that might help you choose what to eat and from where.
#
# Size of training set: 12,690 records
# Size of test set: 4,231 records
#
# FEATURES:
#
# TITLE: The feature of the restaurant which can help identify what and for whom it is suitable for.
# RESTAURANT_ID: A unique ID for each restaurant.
# CUISINES: The variety of cuisines that the restaurant offers.
# TIME: The open hours of the restaurant.
# CITY: The city in which the restaurant is located.
# LOCALITY: The locality of the restaurant.
# RATING: The average rating of the restaurant by customers.
# VOTES: The overall votes received by the restaurant.
# COST: The average cost of a two-person meal.

# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# # Max Rows And Columns

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %% [markdown]
# # Load The Data

# %%
df_train=pd.read_excel("Data_Train.xlsx")
df_train["source"]="train"

# %%
df_test=pd.read_excel("Data_Test.xlsx")
df_test["source"]="test"

# %% [markdown]
# # Concatenate the File to make Final Dataset

# %%
df_food=pd.concat([df_train,df_test])

# %% [markdown]
# # Shape of Dataset

# %%
df_food.shape
# Out:
# (16921, 10)

# %% [markdown]
# # Drop the Duplicate Rows

# %%
df_food.drop_duplicates().shape
# Out:
# (16895, 10)

# %%
df_food.drop_duplicates(inplace=True)

# %% [markdown]
# # Lets reset the index

# %%
df_food.reset_index(drop=True,inplace=True)

# %%
def missing_values_table(df_food):
        zero_val = (df_food == 0.00).astype(int).sum(axis=0)
        mis_val = df_food.isnull().sum()
        mis_val_percent = 100 * df_food.isnull().sum() / len(df_food)
        
        table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        table = table.rename(columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Missing Values'})
        table['Attributes'] = df_food.nunique()
        table['Data Type'] = df_food.dtypes
        
        table = table.sort_values('% of Total Missing Values', ascending=False).round(1)
        
        print ("Your selected dataframe has " + str(df_food.shape[1]) + " columns and " + str(df_food.shape[0]) + " Rows.\n"      
               )

        return table

missing_values_table(df_food)
# Out:
# Your selected dataframe has 10 columns and 16895 Rows.
#                Zero Values  Missing Values  % of Total Missing Values  \
# COST                     0            4230                       25.0
# VOTES                    0            1602                        9.5
# CITY                     0             147                        0.9
# LOCALITY                 0             128                        0.8
# RATING                   0               4                        0.0
# TITLE                    0               0                        0.0
# RESTAURANT_ID            1               0                        0.0
# CUISINES                 0               0                        0.0
# TIME                     0               0                        0.0
# source                   0               0                        0.0
#
#                Attributes Data Type
# COST                   86   float64
# VOTES                2075    object
# CITY                  450    object
# LOCALITY             1636    object
# RATING                 32    object
# TITLE                 123    object
# RESTAURANT_ID       15574     int64
# CUISINES             5183    object
# TIME                 3295    object
# source                  2    object

# %%
for col in df_food.columns:
    if df_food[col].dtype=="object":
        print('**************************',col,'****************************')
        print(df_food[col].unique())
        print()
# Out:
# ************************** TITLE ****************************
# ['CASUAL DINING' 'CASUAL DINING,BAR' 'QUICK BITES' 'DESSERT PARLOR' 'CAFÉ'
#  'MICROBREWERY' 'QUICK BITES,BEVERAGE SHOP' 'CASUAL DINING,IRANI CAFE'
#  'BAKERY,QUICK BITES' 'None' 'BAR,CASUAL DINING' 'BAR' 'PUB'
#  'BEVERAGE SHOP' 'FINE DINING' 'CAFÉ,QUICK BITES'
#  'BEVERAGE SHOP,DESSERT PARLOR' 'SWEET SHOP,QUICK BITES'
#  'DESSERT PARLOR,SWEET SHOP' 'BAKERY' 'BAKERY,DESSERT PARLOR' 'BAR,LOUNGE'
#  'FOOD COURT' 'LOUNGE' 'DESSERT PARLOR,BEVERAGE SHOP'
#  'LOUNGE,CASUAL DINING' 'FOOD TRUCK' 'QUICK BITES,FOOD COURT' 'SWEET SHOP'
#  'BEVERAGE SHOP,FOOD COURT' 'PUB,CASUAL DINING' 'MESS'
#  'MICROBREWERY,CASUAL DINING' 'CASUAL DINING,SWEET SHOP' 'KIOSK'
#  'QUICK BITES,KIOSK' 'CLUB' 'FINE DINING,BAR' 'DESSERT PARLOR,QUICK BITES'
#  'FOOD COURT,QUICK BITES' 'LOUNGE,CAFÉ' 'BAKERY,CONFECTIONERY'
#  'CASUAL DINING,CAFÉ' 'DHABA' 'CAFÉ,DESSERT PARLOR'
#  'QUICK BITES,DESSERT PARLOR' 'PUB,MICROBREWERY' 'LOUNGE,BAR'
#  'DESSERT PARLOR,CAFÉ' 'CAFÉ,BAR' 'SWEET SHOP,CONFECTIONERY'
#  'CASUAL DINING,PUB' 'MICROBREWERY,BAR' 'DESSERT PARLOR,BAKERY'
#  'QUICK BITES,SWEET SHOP' 'BEVERAGE SHOP,QUICK BITES'
#  'CASUAL DINING,LOUNGE' 'CASUAL DINING,CLUB' 'QUICK BITES,CAFÉ' 'BAR,CAFÉ'
#  'CAFÉ,CASUAL DINING' 'QUICK BITES,CASUAL DINING'
#  'CASUAL DINING,MICROBREWERY' 'CASUAL DINING,BAKERY' 'CAFÉ,BAKERY'
#  'MEAT SHOP' 'QUICK BITES,BAKERY' 'BAR,FINE DINING'
#  'SWEET SHOP,CASUAL DINING' 'MEAT SHOP,QUICK BITES' 'PUB,LOUNGE'
#  'BAKERY,CAFÉ' 'COCKTAIL BAR' 'FINE DINING,LOUNGE' 'CONFECTIONERY'
#  'QUICK BITES,BAR' 'BAKERY,FOOD COURT' 'PUB,BAR'
#  'DESSERT PARLOR,FOOD COURT' 'QUICK BITES,FOOD TRUCK'
#  'BAKERY,BEVERAGE SHOP' 'CLUB,BAR' 'BAKERY,SWEET SHOP' 'SWEET SHOP,BAKERY'
#  'CASUAL DINING,FOOD COURT' 'PAAN SHOP' 'BEVERAGE SHOP,CAFÉ'
#  'FOOD COURT,DESSERT PARLOR' 'CLUB,MICROBREWERY' 'CAFÉ,BEVERAGE SHOP'
#  'DESSERT PARLOR,PAAN SHOP' 'MICROBREWERY,LOUNGE' 'LOUNGE,CLUB'
#  'SWEET SHOP,DESSERT PARLOR' 'BAR,PUB' 'CONFECTIONERY,QUICK BITES'
#  'DESSERT PARLOR,KIOSK' 'LOUNGE,PUB' 'SWEET SHOP,BEVERAGE SHOP'
#  'FINE DINING,CAFÉ' 'BEVERAGE SHOP,CASUAL DINING' 'KIOSK,QUICK BITES'
#  'CASUAL DINING,DESSERT PARLOR' 'LOUNGE,FINE DINING' 'PUB,CAFÉ'
#  'CAFÉ,LOUNGE' 'BAR,CLUB' 'COCKTAIL BAR,CASUAL DINING' 'MICROBREWERY,PUB'
#  'CAFÉ,FINE DINING' 'KIOSK,FOOD COURT' 'LOUNGE,MICROBREWERY'
#  'BAR,MICROBREWERY' 'FOOD TRUCK,DESSERT PARLOR' 'IRANI CAFE,BAKERY'
#  'BAKERY,CASUAL DINING' 'PUB,FINE DINING' 'CAFÉ,FOOD COURT'
#  'FINE DINING,MICROBREWERY' 'CLUB,FINE DINING' 'QUICK BITES,MEAT SHOP'
#  'CLUB,CASUAL DINING' 'BHOJANALYA']
#
# ************************** CUISINES ****************************
# ['Malwani, Goan, North Indian' 'Asian, Modern Indian, Japanese'
#  'North Indian, Chinese, Biryani, Hyderabadi' ...
#  'European, Mediterranean, Italian, Sushi'
#  'North Indian, Chinese, Kebab, Juices' 'Sindhi, Street Food']
#
# ************************** TIME ****************************
# ['11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)' '6pm – 11pm (Mon-Sun)'
#  '11am – 3:30pm, 7pm – 11pm (Mon-Sun)' ...
#  '12noon – 4pm, 7pm – 10:30pm (Mon-Sat),12noon –...'
#  '6am – 12:30AM (Mon, Tue, Wed, Thu, Sat, Sun), 6am...'
#  '11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun), 3pm...']
#
# ************************** CITY ****************************
# ['Thane' 'Chennai' 'Mumbai' 'Bangalore' 'Gurgaon' 'Hyderabad' 'Kochi'
#  'Thane West' 'Andheri Lokhandwala' 'New Delhi' 'Andheri West'
#  'Malad East' '682036' 'Bangalor' 'Navi Mumbai' 'Bandra West' 'Delhi'
#  'Noida' 'Bangalore-560066' 'Secunderabad' nan 'India' 'Madhuranagar'
#  'Chennai Teynampet' 'Faridabad' 'Chembur.' 'Maharashtra'
#  'opp gurudwara Shakurpur' 'Telagana Land Line:040-48507016' 'Ghaziabad'
#  'Karnataka' 'Kerala' 'Edappally' 'Kadavanthra' 'Ernakulam Circle kochi'
#  'Bengalore' 'Near Reliance Fresh' 'Kilpauk' 'Bengaluru' 'Kothaguda'
#  'Goregaon West' 'Banglore' 'Tamil Nadu' 'Kakkanad' 'Kochi Elamkulam'
#  'Outer Ring Road' 'Mulund East'
#  'Secunderabad main road near signal NMREC COLLEGE' 'Telangana'
#  'Ponnuruni Kochi' 'Gachibowli' 'Semmancheri'
#  '5th Main Teachers Colony Koramangala Block 1 Bangalore 560034'
#  'Mumbai Mahim' 'Powai (Next to Powai Plaza)' 'Dombivali East'
#  'Kochi Vyttila' 'Kandivali' 'Kochi Palarivattom' 'Dewan Rama Road'
#  'Gurugram' 'Sector 51 Noida' 'Kaloor' 'Besant Nagar'
#  'Arumbakkam chennai-600106.' 'Adjacent To Commercial Street' 'Delhi NCR'
#  'Dwarka' '682035.' 'Kalyan West' 'Avadi' 'Kondapur' 'Mehdipatnam'
#  'Gandipet' 'Velachery' 'Pallavaram' 'Vijaya Nagar' 'BTM Layout'
#  'Chennai 600034.'
#  'Metro Pillar No 21. Mettuguda main road near railway degree college.'
#  'Chennai - 600040' 'JP Nagar Bangalore' 'Madhapur' 'Ernakulam' 'Sarjapur'
#  'Whitefield Bangalore' 'Kochi Chullickal' 'Kochi-683101'
#  'Bangalore - 560076' 'Rohini' 'Hyderabad Behind Vacs Pastries'
#  'Hyderabad neerus emporium.' 'Navi Mumbai.' 'Karol Bagh' 'Perungudi'
#  'Thykoodam' 'Greater Noida' 'Bangalore.' 'Khairatabad' 'chullickal'
#  'Grant Road West' 'Hitech City' 'West Maredpally' 'Mumbai - 400007'
#  'Chennai Padur' 'Chander Nagar New Delhi' 'Nedumbassery' 'MG Road'
#  'Naya Nagar Mira Road' 'Pitampura' 'Lower Parel' 'HBR Layout'
#  'Telangana 500003' 'Rajiv gandhi Nagar' 'New Delhi.' 'Medavakkam'
#  'Sathya Nagar' 'p.o Kochi' 'Behind Ramalayam Temple' 'Palarivattom'
#  'Brigade Road' 'Mumbai.' 'Mumbai Andheri East' 'Virar West' 'B-1 Stage'
#  'Chennai Kovalam' 'Hyderabad.' 'Aluva' 'Telangana 500034'
#  'IOB Bank Kamala Nagar' 'HSR Layout' 'Marine Drive' 'DLF Galleria'
#  'Nallathambi Main Road' 'Chennai opp: Vasanth & co' 'Citypark'
#  'Karnataka 560103' 'Bhayandar' 'Aluva Circle' 'Thammenahalli Village'
#  'SG Palya' 'Attapur.' 'Near Shangrilla Bus Stop' 'Khar (west)' 'Road 3'
#  'Kukatpally' 'Faridabd' 'Telangana 500032' 'Dilsukhnagar'
#  'Mogappair. Chennai' 'Near Munrshwara Temple' 'Off Brigade Road'
#  'khar west' 'Potheri' 'Chennai Perungudi' 'Chennai Thuraipakkam'
#  'OMR Karapakkam' 'Hyderabad-500032' 'Mumbai Dombivali East'
#  'Chennai Thousand Lights' 'Mahim' 'Lingampally' 'Powai'
#  'New Delhi-110024' 'Chennai- 600107' 'Kerala 683104' 'Vasai West.'
#  'Thane (W)' 'Near Santosh Banjara Hyderabad'
#  'Banaswadi (Next to Indian Bank) Bangalore' 'BTM Bangalore'
#  'Greater Kailash 2 New Delhi' 'Secunderabad ECIL'
#  'Bangalore Koramangala 7th Block' 'bangalore : 560085' 'navi mumbai'
#  'Gachibowli Hyderabad'
#  'CPR layout harlur main road opposite to ozone ever green apartment Bangalore -'
#  'ECR NEELANKARAI Chennai 600115' 'ward X11' 'kochi' 'Perumbavoor'
#  'Mira raod east' 'Kerala 682013' 'Chennai.' 'Pokhran Road 2'
#  'Uttar Pradesh' 'Karnataka 560102' 'Mumbai - 400013' 'Naharpar'
#  'Hosur Road' 'Near Bharat Petroleum.'
#  'Chennai (Bang Opposite Indian Bank)' 'Sriram nagar' 'West Mumbai'
#  'Vyttila' 'Banjara Hills' 'MALAPALLIPURAM P .O THRISSUR'
#  'Andheri west Mumbai' 'Karnataka 560043' 'Panampilly Nagar' 'hyderabad'
#  'Borivali East.' 'ECIL' 'Jubilee Hills'
#  'Amrit kaur market opposite new delhi railway station paharganj'
#  'Chennai Opposite 5C Bus stand' 'Telengana' 'Kochi Ravipuram' 'Rajanpada'
#  'Mahabalipuram' 'Secunderabad. WE HAVE NO BRANCHES.' 'Telangana 500081'
#  'Gurgoan' 'Elamakkara' 'Sector 1' 'Bandra W' 'Kolathur'
#  'Chennai Mahabalipuram' '3rd Street' 'Mumbai Chakala' 'Borivali West'
#  'Rodeo Drive Sector 49' 'Pallimukku' 'Delhi 110085' 'Sector 51'
#  'Champapet' 'Andavar Nagar' 'Bangalore - 560103' 'Kerala 690525'
#  'opp mukteshwar ashram powai' 'Nungambakkam' 'BK Guda'
#  'Jogeshwari (w) Mumbai' 'Kukatapally' 'Near Sector 110 Noida' 'Navallur'
#  'Beside Excellency Gardens' 'Mumbai - 80' 'Begumpet'
#  'Maharaja Hotel Beside Gardania Bar' 'Ashok Vihar Phase 1' 'Trivandrum'
#  'Kochi-18' 'Narayanguda' 'Thevera' 'Chennai-40' 'Palm Beach Road'
#  'East Coast Road (ECR)' 'Ramapuram' 'Chennai Chrompet' 'Nandanam' 'Saket'
#  'MG Road Ernakulam' 'Andheri Lokhandwala.' 'Indiranagar' 'Thiruvanmiyur'
#  'Ambattur' 'Banglaore' 'Chennai - 34 Landmark - Near Loyola College'
#  'Anna Nagar West' 'Old Railway Road' 'East Mumbai'
#  'Kanakapura Road Banglore' 'Kochi Kakkanad' 'Kalyan'
#  'Near Ramlila Ground' 'Serilingampally' 'Himayath Nagar' 'Nallala Street'
#  'Anna Salai' 'Old Delhi' 'Wagle Estate' '1st Stage' 'Kochi-16'
#  'Kochi International Airport VIP Road' 'First Street' 'Chenn ai'
#  '6 & 7 - 4/64 Subhash Nagar' '1st Tavarekere' 'Perambur'
#  'Vaishali Ghaziabad' 'Thanisandra' 'Block F' 'Sector 7 Dwarka'
#  'Opposite Barathi Gas Company' 'Vadapalani' 'Kondapur.' 'Badlapur West.'
#  'Kalamassery' 'Palavakkam' 'TCS Synergy park' 'BTM 1st Stage'
#  'Mahadevpura' 'NEW BEL ROAD 560054'
#  'Veliaveetil house Vivekananda Nagar Elamakkara' 'Sholinganallur'
#  'Maharashtra 400102' 'Lower Parel West' 'Tripunithura' 'Mogappair'
#  'Telangana 500070' 'JP Nagar' 'Navi-Mumbai' 'Ashok Nagar' 'Marathahalli'
#  'Haridwar Apartments' 'Kerala 682001 India' 'Karnataka 560037'
#  'Kerala 683585' 'Chennai. (Near Hotel Matshya)' 'Indirapuram'
#  'Begumpet Hyderabad' 'Manikonda'
#  'Bangalore land mark above mahaveer hard ware' 'Kerala 682304'
#  'Rajarajeshwari Nagar bangalore' 'GST Road' 'Fort Kochi'
#  'Lahari Apartments' 'Ramanthapur' 'Mulund west' 'Gurgaon Haryana India'
#  'New Delhi..Near by SBI bank' 'Kochi Aluva 102' 'Phase 1 Bangalore'
#  'Hyderabad Manikonda'
#  'Mumbai This is a Delivery & Take-away Restaurant only.' '10th avenue'
#  'Uppal' 'New Delhi 110075' 'Nizampet' 'Ulsoo' 'Bangalore 560076'
#  'PVR plaza cinema building Connaught Place' 'Gurgaon Haryana' 'Chromepet'
#  'Kerala 682024' 'Janakpuri' 'Secunderabad.' 'chennai'
#  'B.B.M.P East (Karnataka) - 560049' 'Tambaram' 'Malleshwaram Bangalore'
#  'Vadapalani.' 'Dist. Center New Delhi' 'Bangalore Road' 'aluva circle'
#  'Kochi.' 'Thane Mumbai' 'Kadubesanahalli Bangalore' 'Vasai west'
#  'Mig Housing Society' 'Haryana' 'Borivali West.' 'Golf Course Road'
#  'Khar Mumbai' 'Near Jyothinivas College' 'Anna Nagar East' 'Masab Tank'
#  'Vasai Mumbai' 'Panathur Main Road' 'Near Andheri West Station'
#  'opposite to western side of ITPL Service gate' 'Kalkaji' 'APR Chambers'
#  'Tamil Nadu 600102' 'Maharashtra.' 'Gandhinagar Rd'
#  'Near Andheri East Station' 'Whitefield' 'Kerala 682036'
#  'Mira Road Thane Mumbai' 'India Gate New Delhi' 'Bangalore - 560095'
#  'Sholinganallur. Chennai' 'Chennai (Above Bombay Brasserie)' 'Chennai 37'
#  '682024' 'Girgaum' 'Greater Kailash 1 (GK 1) New Delhi' 'Kurla (W)'
#  'Mumbai 400015' 'Thane West Thane West' 'Kochi Panampilly Nagar' 'Marad'
#  'Maharashtra 400092' 'Near Sector 34' 'Mehdipatnam Hyderabad'
#  'Nallagandla' 'Vandalur' 'Mulund West' 'Chennai 40' 'Secunderbad'
#  'MM Nagar' 'Mumbai 400070' 'Chittethukkara' 'BTM' 'Dombivli'
#  'Sahakara Nagar' 'Mohammad Ali Road Mumbai' 'Chennai 600040'
#  'Tavarekere Main Road' 'Community Centre' 'Kerala 682022' 'Delh.'
#  'Sector-6 Noida 201301' 'Kaaraikudi Complex'
#  'Thiruvanmiyur (Opp Eurokids LB Road)' 'Virar Mumbai' 'Tolichowki'
#  'Hyderaba' 'Kerala 682305' 'Alwarpet' 'Kerala 682015'
#  'Mumbai Veera Desai Area' 'Kerala 682018' 'Kerala 682028' 'Suraram'
#  'Chennai Velachery' 'Forum Sujana Mall Opposite to Malaysian township'
#  'Old Hafeezpet' 'Yousufguda' 'Chennai-600008' 'Mumbai Ulhasnagar'
#  'Jogeshwari West Mumbai' 'Chepauk' 'Chowpatty' 'Church Street'
#  'Balavinayagar Nagar Chennai' 'T-Nagar Chennai' 'RA Puram'
#  'Hyderabad.Star hypermarket opposite side Service road'
#  'Chennai Injambakkam' 'Mumbai Mumbra' 'Habsiguda' 'Kurla Mumbai'
#  'Telangana 500027' 'Chenna' 'Kerala 682021' 'Kandivali West'
#  'chennai-119' 'Noida Extention' 'Shihab Thangal Road' 'New Delhi 110011'
#  'Miumbai' 'Borivali (W) Mumbai: 400 092.' 'Vanasthalipuram' 'KK Road'
#  'Chennai - 600018' 'Opposite Ellora Building']
#
# ************************** LOCALITY ****************************
# ['Dombivali East' 'Ramapuram' 'Saligramam' ... 'Off Carter Road'
#  'SRM Back Gate' 'Perry Cross Road']
#
# ************************** RATING ****************************
# ['3.6' '4.2' '3.8' '4.1' '4.0' '4.3' '3.9' '3.3' '3.4' '-' '4.5' '3.5'
#  '4.4' '2.7' '3.7' '4.7' 'NEW' '3.1' '2.5' '4.6' '2.8' nan '3.0' '3.2'
#  '2.6' '2.9' '4.9' '4.8' '2.4' '2.3' '2.0' '2.1' '2.2']
#
# ************************** VOTES ****************************
# ['49 votes' '30 votes' '221 votes' ... '2159 votes' '3807 votes'
#  '1913 votes']
#
# ************************** source ****************************
# ['train' 'test']

# %% [markdown]
# # Print the First 2 Rows of the Dataset

# %%
df_food.head(2)
# Out:
#                TITLE  RESTAURANT_ID                        CUISINES  \
# 0      CASUAL DINING           9438     Malwani, Goan, North Indian
# 1  CASUAL DINING,BAR          13198  Asian, Modern Indian, Japanese
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
#
#       VOTES    COST source
# 0  49 votes  1200.0  train
# 1  30 votes  1500.0  train

# %% [markdown]
# # Irrelavant Columns

# %% [markdown]
# TITLE

# %% [markdown]
# RESTAURANT_ID

# %% [markdown]
# CUISINES

# %% [markdown]
# TIME

# %% [markdown]
# source

# %% [markdown]
# # CLEANING

# %%
df_food.columns
# Out:
# Index(['TITLE', 'RESTAURANT_ID', 'CUISINES', 'TIME', 'CITY', 'LOCALITY',
#        'RATING', 'VOTES', 'COST', 'source'],
#       dtype='object')

# %% [markdown]
# # RESTAURANT_ID

# %%
df_food.drop(columns=["RESTAURANT_ID"],inplace=True)

# %% [markdown]
# # TIME

# %%
df_food.drop(columns=["TIME"],inplace=True)

# %% [markdown]
# # TITLE

# %%
#Now we will divide the "TITLE" column into multiple columns
#First we will find maximum number of TITLE resutarnt having
max_titles=-1
for i in range(len(df_food["TITLE"])):
    temp=len(df_food["TITLE"].iloc[i].split(","))
    if temp>max_titles:
        max_titles=temp
print("Max number of titles are :{}".format(max_titles))
# Out:
# Max number of titles are :2

# %%
t1=list()
t2=list()
for i in range(len(df_food["TITLE"])):
    temp=df_food["TITLE"].iloc[i].split(",")
    try :
        t1.append(temp[0].strip().upper())
    except :
        t1.append('NONE')
    try :
        t2.append(temp[1].strip().upper())
    except :
        t2.append('NONE')

# %%
df_food["Title1"]=t1
df_food["Title2"]=t2

# %% [markdown]
# #Lets drop "TITLE" from the dataset

# %%
df_food.drop(columns=["TITLE"],inplace=True)

# %%
#displaying the dataset
df_food.head(2)
# Out:
#                          CUISINES     CITY        LOCALITY RATING     VOTES  \
# 0     Malwani, Goan, North Indian    Thane  Dombivali East    3.6  49 votes
# 1  Asian, Modern Indian, Japanese  Chennai       Ramapuram    4.2  30 votes
#
#      COST source         Title1 Title2
# 0  1200.0  train  CASUAL DINING   NONE
# 1  1500.0  train  CASUAL DINING    BAR

# %%
df_food.isnull().sum()
# Out:
# CUISINES       0
# CITY         147
# LOCALITY     128
# RATING         4
# VOTES       1602
# COST        4230
# source         0
# Title1         0
# Title2         0
# dtype: int64

# %% [markdown]
# # VOTES

# %%
#lets chcek all the rows where votes are null
df_food.loc[df_food["VOTES"].isnull()].head()
#So we can say there is a pattern where ever resturant is new and rating is missing there are no votes
#We can impute votes by 0 as for new resurants or missing rating its logical to have no votes
# Out:
#                                CUISINES       CITY       LOCALITY RATING  \
# 13                         South Indian      Kochi      Edappally      -
# 62              North Indian, Beverages      Kochi    Kalamassery    NEW
# 69                     Pizza, Fast Food  New Delhi        Kalkaji    NEW
# 85           North Indian, South Indian  Bangalore    Vijay Nagar      -
# 111  Gujarati, Rajasthani, North Indian     Mumbai  Borivali West    NEW
#
#     VOTES   COST source         Title1 Title2
# 13    NaN  400.0  train  CASUAL DINING   NONE
# 62    NaN  200.0  train    QUICK BITES   NONE
# 69    NaN  200.0  train           NONE   NONE
# 85    NaN  300.0  train    QUICK BITES   NONE
# 111   NaN  800.0  train  CASUAL DINING   NONE

# %%
#Imputing missing cells in votes column
df_food["VOTES"].fillna(0,inplace=True)

# %%
#If we closely look at the"VOTES" column it can be conveted to int by stripping off "votes" string wherever present
df_food["VOTES"].loc[df_food["VOTES"].str[-5:]=="votes"]=df_food["VOTES"].loc[df_food["VOTES"].str[-5:]=="votes"].str.rstrip("votes")

# %%
#lets now convert the "VOTES" column to int
df_food["VOTES"]=df_food["VOTES"].astype(int)

# %%
df_food.head(2)
# Out:
#                          CUISINES     CITY        LOCALITY RATING  VOTES  \
# 0     Malwani, Goan, North Indian    Thane  Dombivali East    3.6     49
# 1  Asian, Modern Indian, Japanese  Chennai       Ramapuram    4.2     30
#
#      COST source         Title1 Title2
# 0  1200.0  train  CASUAL DINING   NONE
# 1  1500.0  train  CASUAL DINING    BAR

# %%
df_food.isnull().sum()
# Out:
# CUISINES       0
# CITY         147
# LOCALITY     128
# RATING         4
# VOTES          0
# COST        4230
# source         0
# Title1         0
# Title2         0
# dtype: int64

# %% [markdown]
# # RATING

# %%
df_food["RATING"].value_counts()
# Out:
# 3.9    1638
# 3.8    1601
# 4.0    1493
# 3.7    1437
# 3.6    1261
# 4.1    1214
# 3.5     985
# 4.2     967
# NEW     927
# 3.4     776
# 4.3     740
# -       671
# 3.3     485
# 4.4     484
# 3.2     349
# 4.5     274
# 3.1     263
# 2.9     242
# 3.0     229
# 2.8     191
# 4.6     184
# 2.7     129
# 4.7      89
# 2.6      85
# 2.5      51
# 4.8      49
# 4.9      28
# 2.4      24
# 2.3      15
# 2.2       4
# 2.1       4
# 2.0       2
# Name: RATING, dtype: int64

# %%
#By doing this column can be interpretted as numeric
df_food["RATING"].replace("-",0,inplace=True)
df_food["RATING"].fillna(0,inplace=True)
df_food["RATING"].replace("NEW",0,inplace=True)

# %%
#Lets change the datatypes of"RATING" to float
df_food["RATING"]=df_food["RATING"].astype(float)

# %%
#Lets chcek null values
df_food.isnull().sum()
#From below we have still "CITY" and "LOCALITY" to be imputed
# Out:
# CUISINES       0
# CITY         147
# LOCALITY     128
# RATING         0
# VOTES          0
# COST        4230
# source         0
# Title1         0
# Title2         0
# dtype: int64

# %% [markdown]
# # CUISINES

# %%
#Now we will divide the "CUISINES" column into multiple columns
#First we will find maximum number of CUISINES resutarnt having
max_CUISINESs=-1
for i in range(len(df_food["CUISINES"])):
    temp=len(df_food["CUISINES"].iloc[i].split(","))
    if temp>max_CUISINESs:
        max_CUISINESs=temp
print("Max number of CUISINES are :{}".format(max_CUISINESs))
# Out:
# Max number of CUISINES are :8

# %%
c1=list()
c2=list()
c3=list()
c4=list()
c5=list()
c6=list()
c7=list()
c8=list()
for i in range(len(df_food["CUISINES"])):
    temp=df_food["CUISINES"].iloc[i].split(",")
    try :
        c1.append(temp[0].strip().upper())
    except :
        c1.append('NONE')
    try :
        c2.append(temp[1].strip().upper())
    except :
        c2.append('NONE')
    try :
        c3.append(temp[2].strip().upper())
    except :
        c3.append('NONE')
    try :
        c4.append(temp[3].strip().upper())
    except :
        c4.append('NONE')
    try :
        c5.append(temp[4].strip().upper())
    except :
        c5.append('NONE')
    try :
        c6.append(temp[5].strip().upper())
    except :
        c6.append('NONE')
    try :
        c7.append(temp[6].strip().upper())
    except :
        c7.append('NONE')
    try :
        c8.append(temp[7].strip().upper())
    except :
        c8.append('NONE')

# %%
df_food["CUISINES1"]=c1
df_food["CUISINES2"]=c2
df_food["CUISINES3"]=c3
df_food["CUISINES4"]=c4
df_food["CUISINES5"]=c5
df_food["CUISINES6"]=c6
df_food["CUISINES7"]=c7
df_food["CUISINES8"]=c8

# %% [markdown]
# #Lets drop "CUISINES" from the dataset

# %%
df_food.drop(columns=["CUISINES"],inplace=True)

# %%
#displaying the dataset
df_food.head(2)
# Out:
#       CITY        LOCALITY  RATING  VOTES    COST source         Title1  \
# 0    Thane  Dombivali East     3.6     49  1200.0  train  CASUAL DINING
# 1  Chennai       Ramapuram     4.2     30  1500.0  train  CASUAL DINING
#
#   Title2 CUISINES1      CUISINES2     CUISINES3 CUISINES4 CUISINES5 CUISINES6  \
# 0   NONE   MALWANI           GOAN  NORTH INDIAN      NONE      NONE      NONE
# 1    BAR     ASIAN  MODERN INDIAN      JAPANESE      NONE      NONE      NONE
#
#   CUISINES7 CUISINES8
# 0      NONE      NONE
# 1      NONE      NONE

# %%
df_food.isnull().sum()
# Out:
# CITY          147
# LOCALITY      128
# RATING          0
# VOTES           0
# COST         4230
# source          0
# Title1          0
# Title2          0
# CUISINES1       0
# CUISINES2       0
# CUISINES3       0
# CUISINES4       0
# CUISINES5       0
# CUISINES6       0
# CUISINES7       0
# CUISINES8       0
# dtype: int64

# %% [markdown]
# # CITY

# %%
df_food[(df_food.CITY.isnull())]
# Out:
#       CITY                                           LOCALITY  RATING  VOTES  \
# 129    NaN                                                NaN     3.6    728
# 246    NaN                                 Palarivattom Kochi     3.4     82
# 411    NaN                                                NaN     4.0     29
# 466    NaN                                                NaN     4.2     55
# 481    NaN                                                NaN     3.7    616
# 534    NaN                                                NaN     3.6     30
# 668    NaN                                                NaN     4.1    152
# 788    NaN                                                NaN     0.0      0
# 817    NaN                             shop 7 shikrupa socity     4.1    486
# 826    NaN                                                NaN     4.6    230
# 827    NaN                                                NaN     4.0    254
# 997    NaN                                                NaN     4.0    420
# 1012   NaN                                                NaN     3.5     23
# 1135   NaN                                                NaN     4.4   1074
# 1219   NaN                                                NaN     0.0      0
# 1314   NaN                                                NaN     4.2    106
# 1386   NaN                                                NaN     4.2     61
# 1613   NaN                                                NaN     3.6     15
# 1615   NaN                                                NaN     3.5    115
# 1692   NaN                                                NaN     3.7    135
# 1759   NaN                                                NaN     4.2    213
# 1791   NaN                                                NaN     0.0      0
# 1795   NaN                                                NaN     3.3     81
# 1944   NaN                                                NaN     3.7     90
# 1950   NaN                                                NaN     3.5     57
# 2312   NaN                                                NaN     0.0      0
# 2523   NaN                                                NaN     4.1    601
# 2567   NaN                                                NaN     4.0    284
# 2570   NaN                                                NaN     4.2    283
# 2843   NaN                                                NaN     3.6    199
# 2917   NaN                                                NaN     4.8    161
# 2996   NaN                                                NaN     0.0      0
# 3070   NaN                                                NaN     3.6     33
# 3126   NaN                                                NaN     4.3    110
# 3478   NaN                                                NaN     0.0      0
# 3648   NaN                                                NaN     3.8     34
# 3772   NaN                                                NaN     0.0      0
# 3863   NaN                                                NaN     3.4     14
# 4065   NaN                                                NaN     4.2    215
# 4336   NaN                                                NaN     3.9    564
# 4701   NaN                                                NaN     4.0    254
# 4727   NaN                                                NaN     4.7   2152
# 4939   NaN                                                NaN     3.7     34
# 4979   NaN                                                NaN     4.1     72
# 5038   NaN                                                NaN     3.6    152
# 5088   NaN                                                NaN     4.7   1223
# 5128   NaN                                                NaN     3.5    323
# 5145   NaN                                        Navi Mumbai     3.8    163
# 5293   NaN                                              Kochi     3.4     19
# 5446   NaN                                                NaN     3.5     76
# 5662   NaN                                                NaN     0.0      0
# 5979   NaN                                                NaN     4.6    394
# 6096   NaN                                                NaN     0.0      0
# 6127   NaN                                                NaN     4.3    281
# 6295   NaN                                                NaN     4.6    152
# 6360   NaN                                                NaN     3.6    321
# 6392   NaN                                            Alibaug     4.2    253
# 6446   NaN                                            Chennai     3.5     10
# 6641   NaN                                                NaN     4.1    647
# 6672   NaN                                                NaN     0.0      0
# 6695   NaN                                                NaN     3.5    961
# 6719   NaN                                                NaN     3.6     41
# 6966   NaN                                                NaN     4.6    231
# 7152   NaN                                                NaN     0.0      0
# 7864   NaN                                                NaN     4.5    266
# 8121   NaN                                                NaN     3.8   1102
# 8424   NaN                                                NaN     3.3     49
# 8451   NaN                                          Mathikere     3.7     28
# 8546   NaN                                                NaN     3.8     63
# 8730   NaN                                            Chennai     3.8    284
# 9114   NaN                                          Bangalore     3.9    557
# 9187   NaN                                                NaN     0.0      0
# 9209   NaN                                                NaN     4.0     32
# 9261   NaN                                              Kochi     3.4     14
# 9301   NaN                                                NaN     0.0      0
# 9551   NaN                                                NaN     3.5     44
# 9564   NaN                                                NaN     4.5    613
# 9785   NaN                                                NaN     4.6    165
# 9896   NaN                                                NaN     4.4    201
# 10043  NaN                                                NaN     0.0      0
# 10074  NaN                                                NaN     4.1    106
# 10125  NaN                                                NaN     0.0      0
# 10185  NaN                                                NaN     4.1    305
# 10190  NaN                                             Kalyan     3.5     40
# 10357  NaN                                                NaN     0.0      0
# 10421  NaN                                                NaN     4.4    188
# 10424  NaN                                                NaN     4.6    106
# 10499  NaN                                                NaN     4.1     98
# 10512  NaN                                                NaN     4.7    261
# 10590  NaN                                                NaN     3.8     99
# 10668  NaN                                                NaN     4.2    505
# 10671  NaN                                                NaN     3.6     37
# 10694  NaN                                            Chennai     4.0     68
# 10949  NaN                                                NaN     3.2     50
# 11281  NaN                                                NaN     3.7     75
# 11295  NaN                                                NaN     3.7     33
# 11341  NaN                                                NaN     3.4     15
# 11395  NaN                                                NaN     0.0      0
# 11479  NaN                                            Chennai     3.0    109
# 11561  NaN                                                NaN     0.0      0
# 11838  NaN                                                NaN     4.5    353
# 11843  NaN                                                NaN     3.6     45
# 11921  NaN                                                NaN     4.2    304
# 11937  NaN                                                NaN     4.6     74
# 12022  NaN                                                NaN     4.1     20
# 12055  NaN                                                NaN     4.1    105
# 12246  NaN                                                NaN     0.0      0
# 12258  NaN                                                NaN     3.7    281
# 12292  NaN  Opposite to corporation bank and LIC office ba...     4.3    775
# 12425  NaN                                          Hyderabad     3.1     44
# 12543  NaN                                                NaN     3.7    656
# 12590  NaN                                                NaN     3.6     40
# 12829  NaN                                                NaN     3.5    321
# 12834  NaN                                            Chennai     3.5    161
# 12870  NaN                                                NaN     3.5     37
# 12890  NaN                                                NaN     4.5     50
# 12973  NaN                                                NaN     0.0      0
# 13006  NaN                                                NaN     4.6    115
# 13158  NaN                                                NaN     4.5    177
# 13358  NaN                                                NaN     3.5     13
# 13375  NaN                                            Chennai     3.4     69
# 13509  NaN                                                NaN     3.3    430
# 13566  NaN                                                NaN     0.0      0
# 13703  NaN                                                NaN     3.5     43
# 14019  NaN                             Jaipuria Sunrise Plaza     3.9    362
# 14071  NaN                                                NaN     4.8    109
# 14122  NaN                                                NaN     3.6     27
# 14386  NaN                                                NaN     4.2    306
# 14422  NaN                                                NaN     4.6    225
# 14566  NaN                                                NaN     3.8     42
# 14722  NaN                                                NaN     3.8    753
# 14769  NaN                                                NaN     4.5    224
# 14849  NaN                                                NaN     3.8    139
# 15166  NaN                                                NaN     4.8    128
# 15409  NaN                                                NaN     3.7    680
# 15607  NaN                                                NaN     4.3   1119
# 15653  NaN                                                NaN     4.0    119
# 16033  NaN                                                NaN     4.1    575
# 16108  NaN                                                NaN     3.9     65
# 16192  NaN                                                NaN     0.0      0
# 16220  NaN                                                NaN     3.5     30
# 16224  NaN                                                NaN     2.8     26
# 16285  NaN                                 Maharashtra 400013     4.0   1142
# 16287  NaN                                                NaN     3.5    102
# 16777  NaN                                                NaN     3.7     27
# 16789  NaN                                                NaN     3.5     25
# 16831  NaN                                            Chennai     3.7    124
#
#          COST source          Title1          Title2     CUISINES1  \
# 129     500.0  train            NONE            NONE  NORTH INDIAN
# 246     300.0  train     QUICK BITES            NONE       BIRYANI
# 411     600.0  train            NONE            NONE  NORTH INDIAN
# 466     200.0  train            NONE            NONE  NORTH INDIAN
# 481     250.0  train            NONE            NONE   STREET FOOD
# 534     600.0  train            NONE            NONE  HEALTHY FOOD
# 668     400.0  train            NONE            NONE  NORTH INDIAN
# 788     500.0  train            NONE            NONE  NORTH INDIAN
# 817    1200.0  train   CASUAL DINING            NONE          THAI
# 826     500.0  train            NONE            NONE        BURGER
# 827     400.0  train            NONE            NONE     FAST FOOD
# 997     400.0  train   CASUAL DINING            NONE  NORTH INDIAN
# 1012    400.0  train            NONE            NONE  NORTH INDIAN
# 1135    800.0  train            NONE            NONE       BIRYANI
# 1219    450.0  train            NONE            NONE       CHINESE
# 1314    700.0  train            NONE            NONE         PIZZA
# 1386    600.0  train            NONE            NONE  NORTH INDIAN
# 1613    200.0  train  DESSERT PARLOR            NONE        BAKERY
# 1615    500.0  train     QUICK BITES            NONE  NORTH INDIAN
# 1692    500.0  train            CAFÉ            NONE          CAFE
# 1759   3000.0  train   CASUAL DINING             BAR   CONTINENTAL
# 1791    400.0  train            NONE            NONE        BAKERY
# 1795    200.0  train            NONE            NONE  NORTH INDIAN
# 1944    200.0  train            NONE            NONE      SANDWICH
# 1950    150.0  train   BEVERAGE SHOP            NONE        JUICES
# 2312    150.0  train          BAKERY            NONE        BAKERY
# 2523    450.0  train            NONE            NONE         PIZZA
# 2567    600.0  train            NONE            NONE  NORTH INDIAN
# 2570    700.0  train            NONE            NONE         PIZZA
# 2843    600.0  train     QUICK BITES            NONE     FAST FOOD
# 2917    600.0  train            NONE            NONE         ASIAN
# 2996    800.0  train            NONE            NONE  NORTH INDIAN
# 3070    300.0  train            NONE            NONE         KEBAB
# 3126    500.0  train            NONE            NONE     FAST FOOD
# 3478    600.0  train            NONE            NONE         ASIAN
# 3648    650.0  train            NONE            NONE      AMERICAN
# 3772    400.0  train            NONE            NONE        BIHARI
# 3863    200.0  train            NONE            NONE  NORTH INDIAN
# 4065    600.0  train            NONE            NONE  NORTH INDIAN
# 4336   1700.0  train             BAR   CASUAL DINING         ASIAN
# 4701    700.0  train            NONE            NONE       CHINESE
# 4727   2500.0  train     FINE DINING            NONE    HYDERABADI
# 4939    350.0  train            NONE            NONE   CONTINENTAL
# 4979    800.0  train            NONE            NONE         PIZZA
# 5038    500.0  train            NONE            NONE       CHINESE
# 5088    800.0  train            NONE            NONE         PIZZA
# 5128    500.0  train   CASUAL DINING            NONE  NORTH INDIAN
# 5145    400.0  train   BEVERAGE SHOP  DESSERT PARLOR     BEVERAGES
# 5293   1000.0  train   CASUAL DINING            NONE   CONTINENTAL
# 5446    200.0  train            NONE            NONE  NORTH INDIAN
# 5662    100.0  train   BEVERAGE SHOP            NONE        JUICES
# 5979    650.0  train            NONE            NONE  NORTH INDIAN
# 6096    200.0  train            NONE            NONE  NORTH INDIAN
# 6127    650.0  train            NONE            NONE       CHINESE
# 6295    500.0  train            NONE            NONE  NORTH INDIAN
# 6360    600.0  train            NONE            NONE  NORTH INDIAN
# 6392    950.0  train            CAFÉ            NONE          CAFE
# 6446    400.0  train          BAKERY            NONE        BAKERY
# 6641    700.0  train            NONE            NONE       BIRYANI
# 6672   1000.0  train            NONE            NONE         ASIAN
# 6695    500.0  train            NONE            NONE   CONTINENTAL
# 6719    200.0  train     QUICK BITES            NONE       BIRYANI
# 6966    600.0  train            NONE            NONE  NORTH INDIAN
# 7152    400.0  train            NONE            NONE         PIZZA
# 7864    800.0  train            NONE            NONE      AMERICAN
# 8121    450.0  train            NONE            NONE   CONTINENTAL
# 8424    300.0  train            NONE            NONE  NORTH INDIAN
# 8451    150.0  train     QUICK BITES            NONE     FAST FOOD
# 8546    250.0  train            NONE            NONE      GUJARATI
# 8730    400.0  train   CASUAL DINING            NONE       CHINESE
# 9114   1500.0  train             PUB   CASUAL DINING   FINGER FOOD
# 9187    300.0  train   CASUAL DINING            NONE        KERALA
# 9209    900.0  train            NONE            NONE         ASIAN
# 9261    200.0  train     QUICK BITES            NONE      LEBANESE
# 9301    350.0  train   CASUAL DINING            NONE       CHINESE
# 9551    350.0  train            NONE            NONE  NORTH INDIAN
# 9564   1000.0  train            NONE            NONE       CHINESE
# 9785    800.0  train            NONE            NONE         ASIAN
# 9896    500.0  train            NONE            NONE   CONTINENTAL
# 10043   400.0  train            CAFÉ            NONE          CAFE
# 10074   800.0  train            NONE            NONE       ITALIAN
# 10125   200.0  train   CASUAL DINING            NONE  SOUTH INDIAN
# 10185   350.0  train            NONE            NONE  NORTH INDIAN
# 10190   300.0  train     QUICK BITES            NONE  NORTH INDIAN
# 10357   500.0  train            NONE            NONE  NORTH INDIAN
# 10421   400.0  train            NONE            NONE  NORTH INDIAN
# 10424   800.0  train            NONE            NONE       ITALIAN
# 10499   300.0  train            NONE            NONE  NORTH INDIAN
# 10512  1000.0  train            NONE            NONE         ASIAN
# 10590   350.0  train            NONE            NONE  SOUTH INDIAN
# 10668  1600.0  train          LOUNGE            CAFÉ       CHINESE
# 10671   400.0  train            NONE            NONE       ITALIAN
# 10694   650.0  train   CASUAL DINING            NONE   CONTINENTAL
# 10949   300.0  train            NONE            NONE  SOUTH INDIAN
# 11281   350.0  train            NONE            NONE  SOUTH INDIAN
# 11295   200.0  train            NONE            NONE   CONTINENTAL
# 11341   150.0  train            NONE            NONE     FAST FOOD
# 11395   500.0  train            NONE            NONE  NORTH INDIAN
# 11479   500.0  train     QUICK BITES            NONE       ARABIAN
# 11561   450.0  train            NONE            NONE  NORTH INDIAN
# 11838   600.0  train            NONE            NONE  NORTH INDIAN
# 11843   300.0  train            NONE            NONE  NORTH INDIAN
# 11921   700.0  train            NONE            NONE  NORTH INDIAN
# 11937   650.0  train            NONE            NONE         ASIAN
# 12022   600.0  train            NONE            NONE     FAST FOOD
# 12055   500.0  train            NONE            NONE  NORTH INDIAN
# 12246   200.0  train            NONE            NONE      DESSERTS
# 12258   500.0  train            NONE            NONE  NORTH INDIAN
# 12292   650.0  train   CASUAL DINING            NONE  NORTH INDIAN
# 12425   350.0  train     QUICK BITES            NONE  NORTH INDIAN
# 12543   300.0  train            NONE            NONE       BIRYANI
# 12590   400.0  train            NONE            NONE  HEALTHY FOOD
# 12829     NaN   test            NONE            NONE  NORTH INDIAN
# 12834     NaN   test     QUICK BITES            NONE  NORTH INDIAN
# 12870     NaN   test            NONE            NONE  SOUTH INDIAN
# 12890     NaN   test            NONE            NONE  NORTH INDIAN
# 12973     NaN   test            NONE            NONE  NORTH INDIAN
# 13006     NaN   test            NONE            NONE     FAST FOOD
# 13158     NaN   test            NONE            NONE  NORTH INDIAN
# 13358     NaN   test            NONE            NONE     BEVERAGES
# 13375     NaN   test     QUICK BITES            NONE       ARABIAN
# 13509     NaN   test     QUICK BITES            NONE        ANDHRA
# 13566     NaN   test            NONE            NONE       BIRYANI
# 13703     NaN   test     QUICK BITES            NONE     FAST FOOD
# 14019     NaN   test     QUICK BITES            NONE  NORTH INDIAN
# 14071     NaN   test            NONE            NONE  NORTH INDIAN
# 14122     NaN   test     QUICK BITES            NONE  NORTH INDIAN
# 14386     NaN   test            NONE            NONE  NORTH INDIAN
# 14422     NaN   test            NONE            NONE       ITALIAN
# 14566     NaN   test            NONE            NONE  HEALTHY FOOD
# 14722     NaN   test            NONE            NONE   CONTINENTAL
# 14769     NaN   test            NONE            NONE        AWADHI
# 14849     NaN   test  DESSERT PARLOR            NONE      DESSERTS
# 15166     NaN   test            NONE            NONE  NORTH INDIAN
# 15409     NaN   test   CASUAL DINING            NONE  NORTH INDIAN
# 15607     NaN   test   CASUAL DINING            NONE       MUGHLAI
# 15653     NaN   test            CAFÉ            NONE          CAFE
# 16033     NaN   test            CAFÉ            NONE          CAFE
# 16108     NaN   test            NONE            NONE       BIRYANI
# 16192     NaN   test            NONE            NONE       BENGALI
# 16220     NaN   test            NONE            NONE   STREET FOOD
# 16224     NaN   test            NONE            NONE       BIRYANI
# 16285     NaN   test             PUB   CASUAL DINING   CONTINENTAL
# 16287     NaN   test   CASUAL DINING            NONE  NORTH INDIAN
# 16777     NaN   test            NONE            NONE     FAST FOOD
# 16789     NaN   test     QUICK BITES            NONE       CHINESE
# 16831     NaN   test     QUICK BITES            NONE      LEBANESE
#
#           CUISINES2     CUISINES3     CUISINES4   CUISINES5     CUISINES6  \
# 129    SOUTH INDIAN       CHINESE   CONTINENTAL        NONE          NONE
# 246            NONE          NONE          NONE        NONE          NONE
# 411         CHINESE         PIZZA        BURGER   FAST FOOD          NONE
# 466            NONE          NONE          NONE        NONE          NONE
# 481            NONE          NONE          NONE        NONE          NONE
# 534           SALAD        JUICES          NONE        NONE          NONE
# 668         MUGHLAI       CHINESE          NONE        NONE          NONE
# 788             BBQ       BIRYANI         KEBAB        NONE          NONE
# 817         CHINESE   CONTINENTAL  NORTH INDIAN     ITALIAN          NONE
# 826           PIZZA     FAST FOOD       ITALIAN        NONE          NONE
# 827            CAFE          NONE          NONE        NONE          NONE
# 997         MUGHLAI       BIRYANI         KEBAB  RAJASTHANI          NONE
# 1012        CHINESE          NONE          NONE        NONE          NONE
# 1135   NORTH INDIAN       MUGHLAI    RAJASTHANI        NONE          NONE
# 1219           NONE          NONE          NONE        NONE          NONE
# 1314           NONE          NONE          NONE        NONE          NONE
# 1386        CHINESE          NONE          NONE        NONE          NONE
# 1613       DESSERTS          NONE          NONE        NONE          NONE
# 1615        BENGALI   CONTINENTAL          NONE        NONE          NONE
# 1692           NONE          NONE          NONE        NONE          NONE
# 1759   NORTH INDIAN       ITALIAN       CHINESE        NONE          NONE
# 1791       DESSERTS          NONE          NONE        NONE          NONE
# 1795           NONE          NONE          NONE        NONE          NONE
# 1944           NONE          NONE          NONE        NONE          NONE
# 1950      BEVERAGES     FAST FOOD          NONE        NONE          NONE
# 2312       DESSERTS          NONE          NONE        NONE          NONE
# 2523         BURGER     FAST FOOD  NORTH INDIAN        NONE          NONE
# 2567        CHINESE   CONTINENTAL          NONE        NONE          NONE
# 2570      FAST FOOD          NONE          NONE        NONE          NONE
# 2843   NORTH INDIAN       CHINESE          NONE        NONE          NONE
# 2917           THAI       CHINESE          NONE        NONE          NONE
# 2996        CHINESE          NONE          NONE        NONE          NONE
# 3070   NORTH INDIAN          NONE          NONE        NONE          NONE
# 3126           NONE          NONE          NONE        NONE          NONE
# 3478       JAPANESE       CHINESE          THAI        NONE          NONE
# 3648          ROLLS         WRAPS        BURGER   FAST FOOD          NONE
# 3772           NONE          NONE          NONE        NONE          NONE
# 3863           NONE          NONE          NONE        NONE          NONE
# 4065        BIRYANI          NONE          NONE        NONE          NONE
# 4336       AMERICAN       MEXICAN          NONE        NONE          NONE
# 4701   NORTH INDIAN       MUGHLAI         KEBAB     BIRYANI          NONE
# 4727        MUGHLAI          NONE          NONE        NONE          NONE
# 4939           NONE          NONE          NONE        NONE          NONE
# 4979        ITALIAN          NONE          NONE        NONE          NONE
# 5038          MOMOS          NONE          NONE        NONE          NONE
# 5088        ITALIAN      DESSERTS        BURGER    AMERICAN          NONE
# 5128           NONE          NONE          NONE        NONE          NONE
# 5145      ICE CREAM      DESSERTS          NONE        NONE          NONE
# 5293           NONE          NONE          NONE        NONE          NONE
# 5446           NONE          NONE          NONE        NONE          NONE
# 5662       DESSERTS          NONE          NONE        NONE          NONE
# 5979        CHINESE       ITALIAN   CONTINENTAL        NONE          NONE
# 6096           NONE          NONE          NONE        NONE          NONE
# 6127           THAI     MALAYSIAN      JAPANESE       MOMOS          NONE
# 6295          KEBAB       MUGHLAI          NONE        NONE          NONE
# 6360        MUGHLAI          NONE          NONE        NONE          NONE
# 6392       AMERICAN         ASIAN        BAKERY     BIRYANI       CHINESE
# 6446           NONE          NONE          NONE        NONE          NONE
# 6641        MUGHLAI         KEBAB       BENGALI        NONE          NONE
# 6672        CHINESE         MOMOS          THAI        NONE          NONE
# 6695          ASIAN  HEALTHY FOOD        BURGER     BIRYANI         PIZZA
# 6719           NONE          NONE          NONE        NONE          NONE
# 6966        MUGHLAI       BIRYANI         ROLLS       KEBAB          NONE
# 7152      FAST FOOD          NONE          NONE        NONE          NONE
# 7864         BURGER     BEVERAGES     FAST FOOD        NONE          NONE
# 8121          ASIAN  HEALTHY FOOD        BURGER     BIRYANI         PIZZA
# 8424           NONE          NONE          NONE        NONE          NONE
# 8451      BEVERAGES          NONE          NONE        NONE          NONE
# 8546           NONE          NONE          NONE        NONE          NONE
# 8730         BURGER          NONE          NONE        NONE          NONE
# 9114       AMERICAN   CONTINENTAL        BURGER       PIZZA          NONE
# 9187           NONE          NONE          NONE        NONE          NONE
# 9209       JAPANESE          NONE          NONE        NONE          NONE
# 9261           NONE          NONE          NONE        NONE          NONE
# 9301         KERALA          NONE          NONE        NONE          NONE
# 9551        CHINESE       BIRYANI          NONE        NONE          NONE
# 9564           THAI         ASIAN         SUSHI        POKÉ          NONE
# 9785       JAPANESE       CHINESE     MALAYSIAN        THAI         SUSHI
# 9896        ITALIAN      LEBANESE      SANDWICH      BURGER         PIZZA
# 10043      SANDWICH          NONE          NONE        NONE          NONE
# 10074        BURGER     BEVERAGES          NONE        NONE          NONE
# 10125          NONE          NONE          NONE        NONE          NONE
# 10185     FAST FOOD          NONE          NONE        NONE          NONE
# 10190       CHINESE      SANDWICH   STREET FOOD     BIRYANI          NONE
# 10357   CONTINENTAL  SOUTH INDIAN          NONE        NONE          NONE
# 10421       CHINESE         ROLLS          NONE        NONE          NONE
# 10424        BURGER         PIZZA   CONTINENTAL        NONE          NONE
# 10499          NONE          NONE          NONE        NONE          NONE
# 10512       CHINESE         SUSHI          NONE        NONE          NONE
# 10590   CONTINENTAL          NONE          NONE        NONE          NONE
# 10668   CONTINENTAL          CAFE          NONE        NONE          NONE
# 10671      SANDWICH  HEALTHY FOOD       CHINESE        NONE          NONE
# 10694     FAST FOOD          NONE          NONE        NONE          NONE
# 10949  NORTH INDIAN          NONE          NONE        NONE          NONE
# 11281       BIRYANI          NONE          NONE        NONE          NONE
# 11295          NONE          NONE          NONE        NONE          NONE
# 11341       CHINESE         MOMOS          NONE        NONE          NONE
# 11395       MUGHLAI          NONE          NONE        NONE          NONE
# 11479  NORTH INDIAN       CHINESE          NONE        NONE          NONE
# 11561     BEVERAGES          NONE          NONE        NONE          NONE
# 11838       MUGHLAI       BIRYANI         ROLLS       MOMOS          NONE
# 11843     FAST FOOD       BIRYANI          NONE        NONE          NONE
# 11921       CHINESE  SOUTH INDIAN          NONE        NONE          NONE
# 11937       CHINESE      JAPANESE          POKÉ       SUSHI  HEALTHY FOOD
# 12022          NONE          NONE          NONE        NONE          NONE
# 12055   CONTINENTAL          NONE          NONE        NONE          NONE
# 12246          NONE          NONE          NONE        NONE          NONE
# 12258       CHINESE          NONE          NONE        NONE          NONE
# 12292       BENGALI          NONE          NONE        NONE          NONE
# 12425       CHINESE       MUGHLAI       SEAFOOD        NONE          NONE
# 12543       CHINESE     FAST FOOD  NORTH INDIAN        NONE          NONE
# 12590         SALAD          NONE          NONE        NONE          NONE
# 12829       CHINESE         MOMOS     BEVERAGES        NONE          NONE
# 12834       CHINESE          NONE          NONE        NONE          NONE
# 12870          NONE          NONE          NONE        NONE          NONE
# 12890       CHINESE   CONTINENTAL          NONE        NONE          NONE
# 12973       BIRYANI         KEBAB          NONE        NONE          NONE
# 13006       MEXICAN          NONE          NONE        NONE          NONE
# 13158       CHINESE   CONTINENTAL          NONE        NONE          NONE
# 13358      DESSERTS     FAST FOOD          NONE        NONE          NONE
# 13375  NORTH INDIAN       CHINESE          NONE        NONE          NONE
# 13509    HYDERABADI  NORTH INDIAN          NONE        NONE          NONE
# 13566       MUGHLAI          NONE          NONE        NONE          NONE
# 13703         PIZZA        BURGER     BEVERAGES       ROLLS          NONE
# 14019       CHINESE       MUGHLAI          NONE        NONE          NONE
# 14071       CHINESE     FAST FOOD         MOMOS        NONE          NONE
# 14122          NONE          NONE          NONE        NONE          NONE
# 14386       MUGHLAI       BIRYANI         KEBAB        NONE          NONE
# 14422         PIZZA          NONE          NONE        NONE          NONE
# 14566          NONE          NONE          NONE        NONE          NONE
# 14722         ASIAN  HEALTHY FOOD        BURGER     BIRYANI         PIZZA
# 14769       CHINESE          NONE          NONE        NONE          NONE
# 14849     ICE CREAM          NONE          NONE        NONE          NONE
# 15166       MUGHLAI       BIRYANI          NONE        NONE          NONE
# 15409       MUGHLAI       CHINESE     FAST FOOD        NONE          NONE
# 15607  NORTH INDIAN       BIRYANI          NONE        NONE          NONE
# 15653          NONE          NONE          NONE        NONE          NONE
# 16033       ARABIAN   CONTINENTAL       TURKISH   FAST FOOD        BURGER
# 16108         KEBAB       MUGHLAI          NONE        NONE          NONE
# 16192     FAST FOOD      DESSERTS          NONE        NONE          NONE
# 16220  NORTH INDIAN       CHINESE          NONE        NONE          NONE
# 16224       MUGHLAI          NONE          NONE        NONE          NONE
# 16285       MEXICAN      AMERICAN          NONE        NONE          NONE
# 16287  SOUTH INDIAN       CHINESE       BIRYANI        NONE          NONE
# 16777       ITALIAN         PIZZA      SANDWICH        NONE          NONE
# 16789  NORTH INDIAN          NONE          NONE        NONE          NONE
# 16831          NONE          NONE          NONE        NONE          NONE
#
#        CUISINES7  CUISINES8
# 129         NONE       NONE
# 246         NONE       NONE
# 411         NONE       NONE
# 466         NONE       NONE
# 481         NONE       NONE
# 534         NONE       NONE
# 668         NONE       NONE
# 788         NONE       NONE
# 817         NONE       NONE
# 826         NONE       NONE
# 827         NONE       NONE
# 997         NONE       NONE
# 1012        NONE       NONE
# 1135        NONE       NONE
# 1219        NONE       NONE
# 1314        NONE       NONE
# 1386        NONE       NONE
# 1613        NONE       NONE
# 1615        NONE       NONE
# 1692        NONE       NONE
# 1759        NONE       NONE
# 1791        NONE       NONE
# 1795        NONE       NONE
# 1944        NONE       NONE
# 1950        NONE       NONE
# 2312        NONE       NONE
# 2523        NONE       NONE
# 2567        NONE       NONE
# 2570        NONE       NONE
# 2843        NONE       NONE
# 2917        NONE       NONE
# 2996        NONE       NONE
# 3070        NONE       NONE
# 3126        NONE       NONE
# 3478        NONE       NONE
# 3648        NONE       NONE
# 3772        NONE       NONE
# 3863        NONE       NONE
# 4065        NONE       NONE
# 4336        NONE       NONE
# 4701        NONE       NONE
# 4727        NONE       NONE
# 4939        NONE       NONE
# 4979        NONE       NONE
# 5038        NONE       NONE
# 5088        NONE       NONE
# 5128        NONE       NONE
# 5145        NONE       NONE
# 5293        NONE       NONE
# 5446        NONE       NONE
# 5662        NONE       NONE
# 5979        NONE       NONE
# 6096        NONE       NONE
# 6127        NONE       NONE
# 6295        NONE       NONE
# 6360        NONE       NONE
# 6392    DESSERTS  FAST FOOD
# 6446        NONE       NONE
# 6641        NONE       NONE
# 6672        NONE       NONE
# 6695     ITALIAN  FAST FOOD
# 6719        NONE       NONE
# 6966        NONE       NONE
# 7152        NONE       NONE
# 7864        NONE       NONE
# 8121     ITALIAN  FAST FOOD
# 8424        NONE       NONE
# 8451        NONE       NONE
# 8546        NONE       NONE
# 8730        NONE       NONE
# 9114        NONE       NONE
# 9187        NONE       NONE
# 9209        NONE       NONE
# 9261        NONE       NONE
# 9301        NONE       NONE
# 9551        NONE       NONE
# 9564        NONE       NONE
# 9785        NONE       NONE
# 9896        NONE       NONE
# 10043       NONE       NONE
# 10074       NONE       NONE
# 10125       NONE       NONE
# 10185       NONE       NONE
# 10190       NONE       NONE
# 10357       NONE       NONE
# 10421       NONE       NONE
# 10424       NONE       NONE
# 10499       NONE       NONE
# 10512       NONE       NONE
# 10590       NONE       NONE
# 10668       NONE       NONE
# 10671       NONE       NONE
# 10694       NONE       NONE
# 10949       NONE       NONE
# 11281       NONE       NONE
# 11295       NONE       NONE
# 11341       NONE       NONE
# 11395       NONE       NONE
# 11479       NONE       NONE
# 11561       NONE       NONE
# 11838       NONE       NONE
# 11843       NONE       NONE
# 11921       NONE       NONE
# 11937       NONE       NONE
# 12022       NONE       NONE
# 12055       NONE       NONE
# 12246       NONE       NONE
# 12258       NONE       NONE
# 12292       NONE       NONE
# 12425       NONE       NONE
# 12543       NONE       NONE
# 12590       NONE       NONE
# 12829       NONE       NONE
# 12834       NONE       NONE
# 12870       NONE       NONE
# 12890       NONE       NONE
# 12973       NONE       NONE
# 13006       NONE       NONE
# 13158       NONE       NONE
# 13358       NONE       NONE
# 13375       NONE       NONE
# 13509       NONE       NONE
# 13566       NONE       NONE
# 13703       NONE       NONE
# 14019       NONE       NONE
# 14071       NONE       NONE
# 14122       NONE       NONE
# 14386       NONE       NONE
# 14422       NONE       NONE
# 14566       NONE       NONE
# 14722    ITALIAN  FAST FOOD
# 14769       NONE       NONE
# 14849       NONE       NONE
# 15166       NONE       NONE
# 15409       NONE       NONE
# 15607       NONE       NONE
# 15653       NONE       NONE
# 16033  BEVERAGES       NONE
# 16108       NONE       NONE
# 16192       NONE       NONE
# 16220       NONE       NONE
# 16224       NONE       NONE
# 16285       NONE       NONE
# 16287       NONE       NONE
# 16777       NONE       NONE
# 16789       NONE       NONE
# 16831       NONE       NONE

# %%
df_food["CITY"].fillna("missing",inplace=True)
df_food["LOCALITY"].fillna("missing",inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
for col in df_food.columns:
    if df_food[col].dtype=="object":
        df_food[col]=LabelEncoder().fit_transform(df_food[col])

# %% [markdown]
# # FINAL DATASET

# %%
#Displaying the dataset
df_food.head()
# Out:
#    CITY  LOCALITY  RATING  VOTES    COST  source  Title1  Title2  CUISINES1  \
# 0   400       328     3.6     49  1200.0       1       5      16         61
# 1    75      1214     4.2     30  1500.0       1       5       1          6
# 2    75      1272     3.8    221   800.0       1       5      16         74
# 3   277       161     4.1     24   800.0       1      23      16        102
# 4   277       709     3.8    165   300.0       1       9      16         30
#
#    CUISINES2  CUISINES3  CUISINES4  CUISINES5  CUISINES6  CUISINES7  CUISINES8
# 0         32         72         64         62         50         41         18
# 1         62         45         64         62         50         41         18
# 2         23         14         34         62         50         41         18
# 3         23         70         64         62         50         41         18
# 4         67         70         64         62         50         41         18

# %%
#Lets chcek the datatypes
df_food.dtypes
# Out:
# CITY           int32
# LOCALITY       int32
# RATING       float64
# VOTES          int32
# COST         float64
# source         int32
# Title1         int32
# Title2         int32
# CUISINES1      int32
# CUISINES2      int32
# CUISINES3      int32
# CUISINES4      int32
# CUISINES5      int32
# CUISINES6      int32
# CUISINES7      int32
# CUISINES8      int32
# dtype: object

# %%
df_train=df_food.loc[df_food["source"]==1]
df_test=df_food.loc[df_food["source"]==0]

# %%
#Resetting the index
df_test.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Dropping the source column

# %%
#Dropping the source column
df_train.drop(columns=["source"],inplace=True)
df_test.drop(columns=["source"],inplace=True)

# %%
df_test.drop(columns=["COST"],inplace=True)

# %% [markdown]
# # Lets seprate the input and output from train dataset

# %%
#Lets seprate the input and output from train dataset
df_x=df_train.drop(columns=["COST"])
y=df_train[["COST"]]

# %% [markdown]
# # R2 SCORE Function

# %%
#to find random stat which gives maximum r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %% [markdown]
# # Decision Tree Regressor

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.5054043107795217
# r2 score corresponding to  43  is  0.16635693389990047
# r2 score corresponding to  44  is  0.4436135426763602
# r2 score corresponding to  45  is  0.5622517262036895
# r2 score corresponding to  46  is  0.31215544978633225
# r2 score corresponding to  47  is  0.5964506679706385
# r2 score corresponding to  48  is  0.37304859635913556
# r2 score corresponding to  49  is  0.4546067239959434
# r2 score corresponding to  50  is  0.3752866626540756
# r2 score corresponding to  51  is  0.4675492616723721
# r2 score corresponding to  52  is  0.38330287917873884
# r2 score corresponding to  53  is  0.4162643110421079
# r2 score corresponding to  54  is  0.08521393747217554
# r2 score corresponding to  55  is  0.5477358530496967
# r2 score corresponding to  56  is  0.4301862854956444
# r2 score corresponding to  57  is  0.37082610116219905
# r2 score corresponding to  58  is  0.5298683051699236
# r2 score corresponding to  59  is  0.47891811412832963
# r2 score corresponding to  60  is  0.3517451641784606
# r2 score corresponding to  61  is  -0.02799846837358322
# r2 score corresponding to  62  is  0.2607868884892306
# r2 score corresponding to  63  is  0.4743268445953537
# r2 score corresponding to  64  is  0.42675094028910765
# r2 score corresponding to  65  is  0.3983338233694559
# r2 score corresponding to  66  is  0.4851158690360463
# r2 score corresponding to  67  is  0.48350446052084517
# r2 score corresponding to  68  is  0.443213582341887
# r2 score corresponding to  69  is  0.4741562115528839
# r2 score corresponding to  70  is  0.4226171284331135
# r2 score corresponding to  71  is  0.2782499185914419
# r2 score corresponding to  72  is  0.4831136306044077
# r2 score corresponding to  73  is  0.40316674371685346
# r2 score corresponding to  74  is  0.3417297401499333
# r2 score corresponding to  75  is  0.42973425453088454
# r2 score corresponding to  76  is  0.46026248216852794
# r2 score corresponding to  77  is  0.5331333402880405
# r2 score corresponding to  78  is  0.45745528415404957
# r2 score corresponding to  79  is  0.2573219664342733
# r2 score corresponding to  80  is  0.48220313180870844
# r2 score corresponding to  81  is  0.30487460143392797
# r2 score corresponding to  82  is  0.39045643887531545
# r2 score corresponding to  83  is  0.456355083152571
# r2 score corresponding to  84  is  0.31388291234258503
# r2 score corresponding to  85  is  0.5080010625183021
# r2 score corresponding to  86  is  0.5094623440492192
# r2 score corresponding to  87  is  0.41492882877437165
# r2 score corresponding to  88  is  0.43424176052659613
# r2 score corresponding to  89  is  0.31443878376057977
# r2 score corresponding to  90  is  0.3486511442763619
# r2 score corresponding to  91  is  0.47413136293849945
# r2 score corresponding to  92  is  0.18032687421190063
# r2 score corresponding to  93  is  0.3104660254636561
# r2 score corresponding to  94  is  0.3687215688311203
# r2 score corresponding to  95  is  0.46670024925493425
# r2 score corresponding to  96  is  0.45799445015278883
# r2 score corresponding to  97  is  0.41568152473586306
# r2 score corresponding to  98  is  0.19097361742387153
# r2 score corresponding to  99  is  0.24482221855380593
# max r2 score corresponding to  47  is  0.5964506679706385

# %% [markdown]
# # Random Forest Regressor With GridSearchCV

# %%
#lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.6843664148925639
# r2 score corresponding to  43  is  0.7133398716979644
# r2 score corresponding to  44  is  0.7096978041193713
# r2 score corresponding to  45  is  0.7493135689668959
# r2 score corresponding to  46  is  0.6984267208840558
# r2 score corresponding to  47  is  0.7154112597091882
# r2 score corresponding to  48  is  0.71419281946776
# r2 score corresponding to  49  is  0.6816918874101838
# r2 score corresponding to  50  is  0.7253922972884019
# r2 score corresponding to  51  is  0.7241879487347785
# r2 score corresponding to  52  is  0.6420683385888952
# r2 score corresponding to  53  is  0.7258863468298267
# r2 score corresponding to  54  is  0.6989611288966602
# r2 score corresponding to  55  is  0.7532974191571811
# r2 score corresponding to  56  is  0.7444058841590873
# r2 score corresponding to  57  is  0.6856226056494695
# r2 score corresponding to  58  is  0.6586174023674611
# r2 score corresponding to  59  is  0.7357045598211972
# r2 score corresponding to  60  is  0.7154276154594335
# r2 score corresponding to  61  is  0.5693657392288166
# r2 score corresponding to  62  is  0.6075943030210754
# r2 score corresponding to  63  is  0.7123224566435586
# r2 score corresponding to  64  is  0.6414211406717167
# r2 score corresponding to  65  is  0.7097562795917138
# r2 score corresponding to  66  is  0.7167732028729983
# r2 score corresponding to  67  is  0.7015749877634954
# r2 score corresponding to  68  is  0.6739320490922556
# r2 score corresponding to  69  is  0.6496748179248775
# r2 score corresponding to  70  is  0.7020293433661291
# r2 score corresponding to  71  is  0.6938962276423228
# r2 score corresponding to  72  is  0.7127939374064065
# r2 score corresponding to  73  is  0.7183823923010453
# r2 score corresponding to  74  is  0.6970460535675129
# r2 score corresponding to  75  is  0.655078334081591
# r2 score corresponding to  76  is  0.7327002428687068
# r2 score corresponding to  77  is  0.7412805409649381
# r2 score corresponding to  78  is  0.6595137158984126
# r2 score corresponding to  79  is  0.6831775708885547
# r2 score corresponding to  80  is  0.7385474728557357
# r2 score corresponding to  81  is  0.6908126500799827
# r2 score corresponding to  82  is  0.6981458423956115
# r2 score corresponding to  83  is  0.65415590302053
# r2 score corresponding to  84  is  0.7275765767929033
# r2 score corresponding to  85  is  0.731976238144646
# r2 score corresponding to  86  is  0.7744543711070155
# r2 score corresponding to  87  is  0.7363801417122714
# r2 score corresponding to  88  is  0.720671061721802
# r2 score corresponding to  89  is  0.7235437544559628
# r2 score corresponding to  90  is  0.7244537367280443
# r2 score corresponding to  91  is  0.7050373580438545
# r2 score corresponding to  92  is  0.6702843117030779
# r2 score corresponding to  93  is  0.713392616414541
# r2 score corresponding to  94  is  0.7230587960793584
# r2 score corresponding to  95  is  0.7028868191663328
# r2 score corresponding to  96  is  0.6666932668666019
# r2 score corresponding to  97  is  0.6579962856002626
# r2 score corresponding to  98  is  0.6861282530950668
# r2 score corresponding to  99  is  0.7215392478046965
# max r2 score corresponding to  86  is  0.7744543711070155

# %% [markdown]
# # Light Gradient Boosting

# %%
import lightgbm as lgb
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(df_x,y)
grid_search.best_estimator_
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003313 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1259
# [LightGBM] [Info] Number of data points in the train set: 12665, number of used features: 14
# [LightGBM] [Info] Start training from score 655.400790
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(learning_rate=0.05, max_depth=25, n_estimators=200,
#               num_leaves=900, silent=False)

# %%
lgbr=lgb.LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
       importance_type='split', learning_rate=0.05, max_depth=25,
       min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
       n_estimators=200, n_jobs=-1, num_leaves=900, objective=None,
       random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
       subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
r_state=maxr2_score(lgbr,df_x,y)
#Here we see that lightfbm was faster and better than random forest
# Out:
# r2 score corresponding to  42  is  0.6877826559580793
# r2 score corresponding to  43  is  0.7379192984397247
# r2 score corresponding to  44  is  0.7281130826720265
# r2 score corresponding to  45  is  0.7504765601772823
# r2 score corresponding to  46  is  0.7002914545624641
# r2 score corresponding to  47  is  0.7277972253904553
# r2 score corresponding to  48  is  0.7346416774252735
# r2 score corresponding to  49  is  0.6839700681389962
# r2 score corresponding to  50  is  0.7473913494257428
# r2 score corresponding to  51  is  0.7189867534506267
# r2 score corresponding to  52  is  0.6430360069230676
# r2 score corresponding to  53  is  0.7299699666194563
# r2 score corresponding to  54  is  0.7449546500789319
# r2 score corresponding to  55  is  0.7294294693108274
# r2 score corresponding to  56  is  0.7605971901078331
# r2 score corresponding to  57  is  0.6987853797645991
# r2 score corresponding to  58  is  0.6754925957651507
# r2 score corresponding to  59  is  0.7376148507906067
# r2 score corresponding to  60  is  0.736031399490813
# r2 score corresponding to  61  is  0.7056962605238959
# r2 score corresponding to  62  is  0.6427687127445902
# r2 score corresponding to  63  is  0.730594917410153
# r2 score corresponding to  64  is  0.6386274642303952
# r2 score corresponding to  65  is  0.7271265741982097
# r2 score corresponding to  66  is  0.7309111044763623
# r2 score corresponding to  67  is  0.7097357978895029
# r2 score corresponding to  68  is  0.690788380968099
# r2 score corresponding to  69  is  0.6575116208800051
# r2 score corresponding to  70  is  0.7135042235158822
# r2 score corresponding to  71  is  0.7055807252340847
# r2 score corresponding to  72  is  0.7312135154102484
# r2 score corresponding to  73  is  0.7226901755566173
# r2 score corresponding to  74  is  0.70013250732496
# r2 score corresponding to  75  is  0.6639149736515574
# r2 score corresponding to  76  is  0.739089326809125
# r2 score corresponding to  77  is  0.7453900540605668
# r2 score corresponding to  78  is  0.6596501746810663
# r2 score corresponding to  79  is  0.7251274669938879
# r2 score corresponding to  80  is  0.7405133261131684
# r2 score corresponding to  81  is  0.7192830239062371
# r2 score corresponding to  82  is  0.7187886879536254
# r2 score corresponding to  83  is  0.6437847232038932
# r2 score corresponding to  84  is  0.7366357341064114
# r2 score corresponding to  85  is  0.7158687213891767
# r2 score corresponding to  86  is  0.7679318108629964
# r2 score corresponding to  87  is  0.745760087695678
# r2 score corresponding to  88  is  0.7141970475241115
# r2 score corresponding to  89  is  0.7207123146857015
# r2 score corresponding to  90  is  0.7293055848887431
# r2 score corresponding to  91  is  0.7463960712527176
# r2 score corresponding to  92  is  0.6909003368095203
# r2 score corresponding to  93  is  0.7253296021769141
# r2 score corresponding to  94  is  0.7409948041685428
# r2 score corresponding to  95  is  0.7309892545791488
# r2 score corresponding to  96  is  0.6749438402428606
# r2 score corresponding to  97  is  0.6637457188215475
# r2 score corresponding to  98  is  0.7283367901715138
# r2 score corresponding to  99  is  0.7324974656589816
# max r2 score corresponding to  86  is  0.7679318108629964

# %% [markdown]
# # FINAL PREDICTION

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 86,test_size=0.20)
lgbr.fit(x_train,y_train)
y_pred = lgbr.predict(df_test)

# %%
#lets make the dataframe for cost_pred
cost_pred=pd.DataFrame(y_pred,columns=["COST"])

# %%
#Lets save the submission to csv
cost_pred.to_csv("cost_Predictions.csv",index=False)
